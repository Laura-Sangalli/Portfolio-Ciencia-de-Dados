# %% [markdown]
# ## Análise exploratória de dados da FIFA (2019)
# O arquivo com os respectivos dados pode ser encontrado em https://www.kaggle.com/datasets/winterbreeze/fifa19eda/code.
#
# Inicialmente, será feita um tratamento dos dados nulos e, após isso, partir-se-á para a análise abaixo:
# ### Análises feitas dos dados
# - Qual a influência de *Overall* e *Potential* sobre *Value*?
# - Qual a influência de *Club* sobre *Internatinal Reputation*?
# - Qual a influência de *Internatinal Reputation* sobre *Value*?
# - Qualis os peso e altura médios dos jogadores?
# - Qual a idade média dos jogadores?
# - Qual a média do *Value* dos jogadores? E por clube (*Club*)?
# - Análise percentual de *Preferred Foot* entre os jogadores;
# - Análise quantitativa de ano *Joined* entre os jogadores.

# %%
import pandas as pd

# %%
df = pd.read_csv('fifa_eda.csv')
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred Foot', 'International Reputation',
#        'Skill Moves', 'Position', 'Joined', 'Contract Valid Until', 'Height',
#        'Weight', 'Release Clause'],
#       dtype='object')

# %%
df.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
# 3                       4.0          1.0       GK    2011
# 4                       4.0          4.0      RCM    2015
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0
# 3           2020-01-01  6.333333   168.0        138600.0
# 4           2023-01-01  5.916667   154.0        196400.0

# %%
# deletando a coluna 'ID', porque ela não convém a nenhuma análise
df = df.drop('ID', axis=1)
df.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
# 3                       4.0          1.0       GK    2011
# 4                       4.0          4.0      RCM    2015
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0
# 3           2020-01-01  6.333333   168.0        138600.0
# 4           2023-01-01  5.916667   154.0        196400.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      18207 non-null  object
#  1   Age                       18207 non-null  int64
#  2   Nationality               18207 non-null  object
#  3   Overall                   18207 non-null  int64
#  4   Potential                 18207 non-null  int64
#  5   Club                      17966 non-null  object
#  6   Value                     17955 non-null  float64
#  7   Wage                      18207 non-null  float64
#  8   Preferred Foot            18207 non-null  object
#  9   International Reputation  18159 non-null  float64
#  10  Skill Moves               18159 non-null  float64
#  11  Position                  18207 non-null  object
#  12  Joined                    18207 non-null  int64
#  13  Contract Valid Until      17918 non-null  object
#  14  Height                    18207 non-null  float64
#  15  Weight                    18207 non-null  float64
#  16  Release Clause            18207 non-null  float64
# dtypes: float64(7), int64(4), object(6)
# memory usage: 2.4+ MB

# %% [markdown]
# ## Limpeza e tratamento de dados
# Podemos observar que há alguns dados faltantes. Precisamos, portanto, manipulá-los.

# %%
df.isna().sum()
# Out:
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                        241
# Value                       252
# Wage                          0
# Preferred Foot                0
# International Reputation     48
# Skill Moves                  48
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
# análise da coluna 'Club'
# nessa coluna, cria-se uma nova categoria única, chamada 'sem clube/clube desconhecido' quee serão adicionadas em lugar dos valores nan
len(list(df.Club.unique()))
# Out:
# 652

# %%
df.loc[df['Club'].isna()]
# Out:
#                  Name  Age Nationality  Overall  Potential Club  Value  Wage  \
# 452        L. Paredes   24   Argentina       80         85  NaN    NaN   0.0
# 538      A. Granqvist   33      Sweden       80         80  NaN    NaN   0.0
# 568          A. Lunev   26      Russia       79         81  NaN    NaN   0.0
# 677      I. Smolnikov   29      Russia       79         79  NaN    NaN   0.0
# 874         A. Dzyuba   29      Russia       78         78  NaN    NaN   0.0
# ...               ...  ...         ...      ...        ...  ...    ...   ...
# 17197        V. Kaith   21       India       55         64  NaN    NaN   0.0
# 17215        K. Taimi   26     Finland       55         57  NaN    NaN   0.0
# 17339        S. Passi   23       India       54         63  NaN    NaN   0.0
# 17436  D. Lalhlimpuia   20       India       54         67  NaN    NaN   0.0
# 17539        C. Singh   21       India       53         62  NaN    NaN   0.0
#
#       Preferred Foot  International Reputation  Skill Moves Position  Joined  \
# 452            Right                       2.0          4.0       CM    2016
# 538            Right                       2.0          2.0      LCB    2016
# 568            Right                       1.0          1.0       GK    2016
# 677            Right                       2.0          3.0       RB    2016
# 874            Right                       2.0          3.0       ST    2016
# ...              ...                       ...          ...      ...     ...
# 17197          Right                       1.0          1.0       GK    2016
# 17215          Right                       1.0          2.0       RB    2016
# 17339          Right                       1.0          2.0       RM    2016
# 17436          Right                       1.0          2.0       GK    2016
# 17539          Right                       1.0          2.0       LB    2016
#
#       Contract Valid Until    Height  Weight  Release Clause
# 452                    NaN  5.916667   165.0     4585.060806
# 538                    NaN  6.333333   185.0     4585.060806
# 568                    NaN  6.166667   176.0     4585.060806
# 677                    NaN  5.833333   154.0     4585.060806
# 874                    NaN  6.416667   201.0     4585.060806
# ...                    ...       ...     ...             ...
# 17197                  NaN  6.166667   176.0     4585.060806
# 17215                  NaN  6.333333   187.0     4585.060806
# 17339                  NaN  5.750000   143.0     4585.060806
# 17436                  NaN  6.000000   168.0     4585.060806
# 17539                  NaN  6.250000   174.0     4585.060806
#
# [241 rows x 17 columns]

# %%
df['Club'].fillna('without club/unknowed club', inplace=True)
# Out:
# /tmp/ipykernel_16927/1933041980.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Club'].fillna('without club/unknowed club', inplace=True)

# %%
df.isna().sum()
# Out:
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                          0
# Value                       252
# Wage                          0
# Preferred Foot                0
# International Reputation     48
# Skill Moves                  48
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
# preenchendo os valores de 'Value' com zero. Como eles não estão definidos, é o mais lógico a se fazer
df['Value'].fillna(0, inplace=True)
df.isna().sum()
# Out:
# /tmp/ipykernel_16927/3495974242.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Value'].fillna(0, inplace=True)
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                          0
# Value                         0
# Wage                          0
# Preferred Foot                0
# International Reputation     48
# Skill Moves                  48
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
# agora, o tratamento dos dados nulos em International Reputation
# verifica-se inicialmente qual é o 'Overall' minimo para cada um dos valores únicos de 'International Reputation'. Em seguida,
# substitui-se o 'International Reputation' nulo pelo valor que o 'Overall' do respectivo jogador encontra-se no intervalo.

df.groupby('International Reputation')['Overall'].min()
# Out:
# International Reputation
# 1.0    46
# 2.0    54
# 3.0    68
# 4.0    80
# 5.0    85
# Name: Overall, dtype: int64

# %%
# podemos observar que o 'Overall' de todos esses jogadores é 62. Logo, podemos subsituir todos os 'International Reputation' nulos por 3.0
# variável x utilizada só para caso de análise
x = df.loc[df['International Reputation'].isna()]

# %%
x['Overall'].unique()
# Out:
# array([62])

# %%
df['International Reputation'].fillna(3.0, inplace=True)
# Out:
# /tmp/ipykernel_16927/3998462528.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['International Reputation'].fillna(3.0, inplace=True)

# %%
df.isna().sum()
# Out:
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                          0
# Value                         0
# Wage                          0
# Preferred Foot                0
# International Reputation      0
# Skill Moves                  48
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
df.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
# 3                       4.0          1.0       GK    2011
# 4                       4.0          4.0      RCM    2015
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0
# 3           2020-01-01  6.333333   168.0        138600.0
# 4           2023-01-01  5.916667   154.0        196400.0

# %%
# 'Skill Moves': como é difícil definir um critério para atribuir as habilidades de movimento com esses dados, substituiremos
# os dados nulos pela média geral não-nula
media = int(df['Skill Moves'].mean(numeric_only=True))
media
# Out:
# 2

# %%
df['Skill Moves'].fillna(media, inplace=True)
df.isna().sum()
# Out:
# /tmp/ipykernel_16927/3505749593.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Skill Moves'].fillna(media, inplace=True)
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                          0
# Value                         0
# Wage                          0
# Preferred Foot                0
# International Reputation      0
# Skill Moves                   0
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
# 'Contract Valid Until': é possível ver que esse dado está em formato Object, mas pode ser convertido para datetime
df['Contract Valid Until'] = pd.to_datetime(df['Contract Valid Until'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      18207 non-null  object
#  1   Age                       18207 non-null  int64
#  2   Nationality               18207 non-null  object
#  3   Overall                   18207 non-null  int64
#  4   Potential                 18207 non-null  int64
#  5   Club                      18207 non-null  object
#  6   Value                     18207 non-null  float64
#  7   Wage                      18207 non-null  float64
#  8   Preferred Foot            18207 non-null  object
#  9   International Reputation  18207 non-null  float64
#  10  Skill Moves               18207 non-null  float64
#  11  Position                  18207 non-null  object
#  12  Joined                    18207 non-null  int64
#  13  Contract Valid Until      17918 non-null  datetime64[ns]
#  14  Height                    18207 non-null  float64
#  15  Weight                    18207 non-null  float64
#  16  Release Clause            18207 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int64(4), object(5)
# memory usage: 2.4+ MB

# %%
# agora, podemos fazer uma análise de dados mais robusta
df.loc[df['Contract Valid Until'].isna()]
# Out:
#                  Name  Age Nationality  Overall  Potential  \
# 452        L. Paredes   24   Argentina       80         85
# 538      A. Granqvist   33      Sweden       80         80
# 568          A. Lunev   26      Russia       79         81
# 677      I. Smolnikov   29      Russia       79         79
# 874         A. Dzyuba   29      Russia       78         78
# ...               ...  ...         ...      ...        ...
# 17197        V. Kaith   21       India       55         64
# 17215        K. Taimi   26     Finland       55         57
# 17339        S. Passi   23       India       54         63
# 17436  D. Lalhlimpuia   20       India       54         67
# 17539        C. Singh   21       India       53         62
#
#                              Club  Value  Wage Preferred Foot  \
# 452    without club/unknowed club    0.0   0.0          Right
# 538    without club/unknowed club    0.0   0.0          Right
# 568    without club/unknowed club    0.0   0.0          Right
# 677    without club/unknowed club    0.0   0.0          Right
# 874    without club/unknowed club    0.0   0.0          Right
# ...                           ...    ...   ...            ...
# 17197  without club/unknowed club    0.0   0.0          Right
# 17215  without club/unknowed club    0.0   0.0          Right
# 17339  without club/unknowed club    0.0   0.0          Right
# 17436  without club/unknowed club    0.0   0.0          Right
# 17539  without club/unknowed club    0.0   0.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 452                         2.0          4.0       CM    2016
# 538                         2.0          2.0      LCB    2016
# 568                         1.0          1.0       GK    2016
# 677                         2.0          3.0       RB    2016
# 874                         2.0          3.0       ST    2016
# ...                         ...          ...      ...     ...
# 17197                       1.0          1.0       GK    2016
# 17215                       1.0          2.0       RB    2016
# 17339                       1.0          2.0       RM    2016
# 17436                       1.0          2.0       GK    2016
# 17539                       1.0          2.0       LB    2016
#
#       Contract Valid Until    Height  Weight  Release Clause
# 452                    NaT  5.916667   165.0     4585.060806
# 538                    NaT  6.333333   185.0     4585.060806
# 568                    NaT  6.166667   176.0     4585.060806
# 677                    NaT  5.833333   154.0     4585.060806
# 874                    NaT  6.416667   201.0     4585.060806
# ...                    ...       ...     ...             ...
# 17197                  NaT  6.166667   176.0     4585.060806
# 17215                  NaT  6.333333   187.0     4585.060806
# 17339                  NaT  5.750000   143.0     4585.060806
# 17436                  NaT  6.000000   168.0     4585.060806
# 17539                  NaT  6.250000   174.0     4585.060806
#
# [289 rows x 17 columns]

# %%
# variavel x passa a ser utilizada de novo, para uma análise dos clubes sem
# dados de fim de contrato
x = df.loc[df['Contract Valid Until'].isna()]
x.Club.unique()
# descobre-se que são muitos clubes sem dados de vencimento do contrato
# Out:
# array(['without club/unknowed club', 'Rochdale', 'Boyacá Chicó FC',
#        'Notts County', 'Brescia', 'Hamilton Academical FC',
#        'Śląsk Wrocław', 'Club Atlético Aldosivi', 'Everton', 'Hobro IK',
#        'HJK Helsinki', 'AS Béziers', 'SV Mattersburg', 'Tranmere Rovers',
#        'Shanghai Greenland Shenhua FC', 'Itagüí Leones FC', 'NAC Breda',
#        'Malmö FF', 'Carlisle United', 'VfB Stuttgart', 'Dundee FC',
#        'Suwon Samsung Bluewings', 'Al Wehda', 'CD Palestino',
#        'Albacete BP', 'Al Nassr', 'TSV 1860 München',
#        'FC Admira Wacker Mödling', 'Grenoble Foot 38', 'Oldham Athletic',
#        'Hammarby IF', 'Miedź Legnica', 'Jaguares de Córdoba', 'Bologna',
#        'CD Antofagasta', 'Kristiansund BK', 'Al Raed', 'Deportes Iquique',
#        'FC Utrecht', 'Perugia', 'Montpellier HSC', 'Gyeongnam FC',
#        'Tiburones Rojos de Veracruz', 'Guizhou Hengfeng FC'], dtype=object)

# %%
# substituem-se os valores nan com o valor máximo de validade de contrato
maximo = df['Contract Valid Until'].max()

df['Contract Valid Until'].fillna(maximo, inplace=True)
df.isna().sum()
# agora, não há mais dados nulos. Vamos partir para a análise!
# Out:
# /tmp/ipykernel_16927/4156595288.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Contract Valid Until'].fillna(maximo, inplace=True)
# Name                        0
# Age                         0
# Nationality                 0
# Overall                     0
# Potential                   0
# Club                        0
# Value                       0
# Wage                        0
# Preferred Foot              0
# International Reputation    0
# Skill Moves                 0
# Position                    0
# Joined                      0
# Contract Valid Until        0
# Height                      0
# Weight                      0
# Release Clause              0
# dtype: int64

# %% [markdown]
# ## Análise de dados

# %%
from itertools import starmap
# Qual a influência de Overall e Potential sobre Value?
import matplotlib.pyplot as plt
import plotly.express as px

grafico = px.scatter(df, x='Overall', y='Potential', size='Value')
grafico.update_layout(title='Comparação entre Overall Potential e Value dos jogadores da FIFA 2019')

grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dd76aec4-8fc8-470f-a2f7-49d92416f8d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd76aec4-8fc8-470f-a2f7-49d92416f8d7")) {                    Plotly.newPlot(                        "dd76aec4-8fc8-470f-a2f7-49d92416f8d7",                        [{"hovertemplate":"Overall=%{x}\u003cbr\u003ePotential=%{y}\u003cbr\u003eValue=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","size":[110500.0,77000.0,118500.0,72000.0,102000.0,93000.0,67000.0,80000.0,51000.0,68000.0,77000.0,76500.0,44000.0,60000.0,63000.0,89000.0,83500.0,78000.0,58000.0,53500.0,51500.0,60000.0,38000.0,64500.0,27000.0,81000.0,69500.0,59500.0,69500.0,62000.0,73500.0,73500.0,69500.0,59000.0,46000.0,43000.0,60000.0,36000.0,57000.0,24000.0,30000.0,4000.0,57000.0,64500.0,51000.0,64000.0,30500.0,62500.0,52000.0,38000.0,45000.0,34000.0,46500.0,46500.0,34000.0,61000.0,59500.0,41500.0,52000.0,44500.0,56500.0,53000.0,50000.0,55000.0,36500.0,46500.0,45000.0,45500.0,43500.0,35000.0,30000.0,39000.0,44000.0,30000.0,43500.0,18000.0,21500.0,46500.0,50500.0,54000.0,50000.0,36500.0,40500.0,50500.0,40500.0,38000.0,45000.0,45000.0,37500.0,28500.0,37000.0,37000.0,32000.0,37500.0,39000.0,30000.0,26000.0,37500.0,30500.0,33000.0,38500.0,35500.0,9000.0,26000.0,15500.0,37000.0,21500.0,22000.0,9000.0,14000.0,34000.0,34000.0,32000.0,34000.0,40500.0,36500.0,42500.0,42500.0,34000.0,35500.0,31500.0,38000.0,39000.0,31500.0,42000.0,37000.0,25000.0,31500.0,29500.0,29500.0,30000.0,27000.0,24000.0,22000.0,31000.0,24500.0,32000.0,27500.0,29500.0,25000.0,30500.0,24000.0,29000.0,24000.0,27500.0,16500.0,23000.0,19000.0,25000.0,19000.0,18000.0,30000.0,4200.0,15500.0,15500.0,40000.0,41000.0,28000.0,22500.0,28500.0,30500.0,34000.0,34000.0,35500.0,34000.0,29500.0,36500.0,34500.0,33000.0,34000.0,30500.0,32500.0,27000.0,33000.0,32000.0,20000.0,35000.0,28500.0,30000.0,34500.0,25000.0,26000.0,28500.0,33000.0,32500.0,31500.0,31000.0,27000.0,24500.0,24000.0,26500.0,19000.0,26500.0,30500.0,25500.0,26500.0,21000.0,21000.0,21000.0,25500.0,24000.0,13000.0,19000.0,21000.0,26000.0,30500.0,27500.0,19000.0,26000.0,17500.0,20000.0,24500.0,15500.0,16500.0,20000.0,20000.0,20000.0,17500.0,13000.0,22000.0,24000.0,11500.0,13000.0,8000.0,6000.0,19500.0,27000.0,29000.0,32500.0,29000.0,16500.0,6500.0,14000.0,29500.0,29000.0,25000.0,31500.0,21500.0,25500.0,26000.0,26000.0,24500.0,20000.0,29500.0,30500.0,24500.0,29000.0,25500.0,26500.0,25500.0,26500.0,20000.0,30000.0,26000.0,26500.0,21500.0,22500.0,22500.0,20500.0,23500.0,21000.0,18500.0,27500.0,29500.0,21000.0,28500.0,18000.0,23500.0,26000.0,26000.0,28500.0,28500.0,22500.0,21000.0,21000.0,26500.0,18500.0,19500.0,21500.0,19500.0,27000.0,22500.0,21500.0,21000.0,22000.0,18500.0,21000.0,17000.0,21000.0,25000.0,18500.0,12500.0,22500.0,20000.0,22000.0,21000.0,18000.0,21500.0,9000.0,17000.0,12500.0,12500.0,23000.0,15000.0,20000.0,15000.0,19000.0,15000.0,12500.0,13500.0,12500.0,12500.0,13500.0,12500.0,4800.0,8000.0,8000.0,3000.0,1500.0,27000.0,17000.0,26500.0,21000.0,26000.0,20000.0,24000.0,26000.0,21000.0,25000.0,24000.0,17000.0,20500.0,22500.0,18500.0,24500.0,24500.0,21500.0,22500.0,17000.0,20000.0,24500.0,19000.0,20500.0,24000.0,19500.0,22500.0,16000.0,22000.0,18500.0,18500.0,25500.0,22500.0,20000.0,17000.0,18000.0,21500.0,18000.0,21000.0,16500.0,15000.0,17000.0,22000.0,23500.0,18000.0,22000.0,17500.0,17000.0,19500.0,16000.0,13000.0,19000.0,21500.0,16500.0,17500.0,17500.0,18500.0,21000.0,16000.0,15500.0,17500.0,23000.0,18500.0,18000.0,16000.0,17500.0,10000.0,13000.0,14000.0,14000.0,11000.0,15500.0,15000.0,7000.0,15500.0,17000.0,21000.0,14500.0,17500.0,16500.0,10000.0,9000.0,15000.0,11000.0,8000.0,14000.0,14000.0,17500.0,11000. ...

# %% [markdown]
# Portanto, podemos ver que há uma clara relação entre essas variáveis

# %%
# Qual a influência de Club sobre Internatinal Reputation?
reputacao_por_clube = df[['Club', 'International Reputation']].sort_values(by=['International Reputation'],ascending=False)
reputacao_por_clube
# Out:
#                           Club  International Reputation
# 22           FC Bayern München                       5.0
# 109                  LA Galaxy                       5.0
# 7                 FC Barcelona                       5.0
# 0                 FC Barcelona                       5.0
# 1                     Juventus                       5.0
# ...                        ...                       ...
# 7107                  Al Batin                       1.0
# 7106  FC Admira Wacker Mödling                       1.0
# 7105            Olympiacos CFP                       1.0
# 7104               Trabzonspor                       1.0
# 7112             Os Belenenses                       1.0
#
# [18207 rows x 2 columns]

# %% [markdown]
# Uma análise detalalhada desse DataFrame revelará que times mais conhecidos mundialmente, de fato, possuem um

# %%
# Qual a influência de Internatinal Reputation sobre Value?
import seaborn as sns
sns.lineplot(x='International Reputation', y='Value', data=df)
plt.title('Internatinal Reputation vs. Value - Jogadores FIFA 2019')
# Out:
# Text(0.5, 1.0, 'Internatinal Reputation vs. Value - Jogadores FIFA 2019')

# %% [markdown]
# Portanto, podese observar uma clara relação entre a International Reputation e Value

# %%
# Quais são o peso e altura médios dos jogadores?
peso = df.Weight.mean().round(2)
altura = df.Height.mean().round(2)
print(f'Peso: {peso}, Altura = {altura}')
# Out:
# Peso: 165.98, Altura = 5.95

# %%
# Qual a idade média dos jogadores?
print(int(df.Age.mean()), 'anos')
# Out:
# 25 anos

# %%
# Qual a média do Value dos jogadores? E por clube (Club)?
media_por_clube = df.groupby('Club')[['Value']].mean().round(2)
print(f'Média geral: {df.Value.mean().round(2)}. \n Media por clube: {media_por_clube}')
# Out:
# Média geral: 2410.7.
#  Media por clube:                               Value
# Club
#  SSV Jahn Regensburg         796.38
# 1. FC Heidenheim 1846        981.79
# 1. FC Kaiserslautern         622.88
# 1. FC Köln                  4853.93
# 1. FC Magdeburg              789.42
# ...                             ...
# without club/unknowed club     0.00
# Çaykur Rizespor             1728.00
# Örebro SK                    395.74
# Östersunds FK                599.09
# Śląsk Wrocław                383.80
#
# [652 rows x 1 columns]

# %%
# Análise percentual de Preferred Foot entre os jogadores;
sns.histplot(df['Preferred Foot'], kde=False, color='Yellow')
plt.title('Preferred Foot among Soccer Players')
# Out:
# Text(0.5, 1.0, 'Preferred Foot among Soccer Players')

# %%
# Análise quantitativa de ano Joined entre os jogadores.

grafico = sns.histplot(df['Joined'], kde=True, color='Grey')
grafico.figure.set_size_inches(20, 6)
grafico.set_xticks([x for x in range(1990, 2019)])
plt.title('Jogadores de futebol contratados por ano')
# Out:
# Text(0.5, 1.0, 'Jogadores de futebol contratados por ano')
